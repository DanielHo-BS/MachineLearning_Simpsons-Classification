# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import pathlib

# %%
path="theSimpsons-train/train"
data_dir = pathlib.Path(path)

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 96929

# %%
batch_size = 16
img_height = 180
img_width = 180

train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 96929 files belonging to 50 classes.
# Using 77544 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 96929 files belonging to 50 classes.
# Using 19385 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['abraham_grampa_simpson', 'agnes_skinner', 'apu_nahasapeemapetilon', 'barney_gumble', 'bart_simpson', 'brandine_spuckler', 'carl_carlson', 'charles_montgomery_burns', 'chief_wiggum', 'cletus_spuckler', 'comic_book_guy', 'disco_stu', 'dolph_starbeam', 'duff_man', 'edna_krabappel', 'fat_tony', 'gary_chalmers', 'gil', 'groundskeeper_willie', 'homer_simpson', 'jimbo_jones', 'kearney_zzyzwicz', 'kent_brockman', 'krusty_the_clown', 'lenny_leonard', 'lionel_hutz', 'lisa_simpson', 'lunchlady_doris', 'maggie_simpson', 'marge_simpson', 'martin_prince', 'mayor_quimby', 'milhouse_van_houten', 'miss_hoover', 'moe_szyslak', 'ned_flanders', 'nelson_muntz', 'otto_mann', 'patty_bouvier', 'principal_skinner', 'professor_john_frink', 'rainier_wolfcastle', 'ralph_wiggum', 'selma_bouvier', 'sideshow_bob', 'sideshow_mel', 'snake_jailbird', 'timothy_lovejoy', 'troy_mcclure', 'waylon_smithers']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (16, 180, 180, 3)
# (16,)

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
import keras
from keras.models import Sequential
from keras.models import Model
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau, TensorBoard
from keras import optimizers, losses, activations, models
from keras.layers import Convolution2D, Dense, Input, Flatten, Dropout, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, Concatenate,Dropout
from keras.applications.inception_v3 import InceptionV3
from keras.applications.resnet import ResNet50

# %%
num_classes = 50

def model_ResNet50():
    base_model = ResNet50(weights='imagenet',
                          include_top=False,
                          pooling=max,
                          input_shape=(img_height,img_width,3))

    for layer in base_model.layers:
        layer.trainable = False

    add_model = Sequential()
    add_model.add(base_model)
    add_model.add(GlobalAveragePooling2D())
    add_model.add(Dropout(0.2))
    add_model.add(Dense(1024, activation='relu'))
    add_model.add(Dense(num_classes, activation='softmax'))

    model = add_model

    model.compile(
      optimizer='adam',
      loss=tf.losses.SparseCategoricalCrossentropy(),
      metrics=['accuracy'])

    model.summary()
    return model

def model_InceptionV3():
    base_model = InceptionV3(weights='imagenet',
                          include_top=False,
                          pooling=max,
                          input_shape=(img_height,img_width,3))

    for layer in base_model.layers:
        layer.trainable = False

    add_model = Sequential()
    add_model.add(base_model)
    add_model.add(GlobalAveragePooling2D())
    add_model.add(Dropout(0.2))
    add_model.add(Dense(1024, activation='relu'))
    add_model.add(Dense(num_classes, activation='softmax'))

    model = add_model

    model.compile(
      optimizer='adam',
      loss=tf.losses.SparseCategoricalCrossentropy(),
      metrics=['accuracy'])

    model.summary()
    return model

# %%
model=model_ResNet50()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 6, 6, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                51250
# =================================================================
# Total params: 25,737,138
# Trainable params: 2,149,426
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
# 創建模型儲存目錄：
model_dir = 'lab-logs/models/'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
    
# TensorBoard回調函數會幫忙紀錄訓練資訊，並存成TensorBoard的紀錄檔
log_dir = os.path.join('lab-logs', 'model-2')
model_cbk = keras.callbacks.TensorBoard(log_dir=log_dir)
# ModelCheckpoint回調函數幫忙儲存網路模型，可以設定只儲存最好的模型，「monitor」表示被監測的數據，「mode」min則代表監測數據越小越好。
model_mckp = keras.callbacks.ModelCheckpoint(model_dir + '/Best-model-2.h5',monitor='val_accuracy',save_best_only=True,mode='max')

# %%
#載入訓練好的模型 
#model = keras.models.load_model('lab-logs/models/Best-model-1.h5')

# %%
#開始訓練
history = model.fit(train_ds,
          callbacks=[model_cbk, model_mckp],
          epochs=5,
          validation_data=val_ds)
# Out:
# c:\users\d\anaconda3\envs\yolo\lib\site-packages\keras\utils\generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 1/5
# 4847/4847 [==============================] - 3741s 771ms/step - loss: 1.4907 - accuracy: 0.5952 - val_loss: 0.9553 - val_accuracy: 0.7329
# Epoch 2/5
# 4847/4847 [==============================] - 5163s 1s/step - loss: 0.9523 - accuracy: 0.7315 - val_loss: 0.8165 - val_accuracy: 0.7715
# Epoch 3/5
# 4847/4847 [==============================] - 5419s 1s/step - loss: 0.7892 - accuracy: 0.7733 - val_loss: 0.7325 - val_accuracy: 0.7948
# Epoch 4/5
# 4847/4847 [==============================] - 5346s 1s/step - loss: 0.6979 - accuracy: 0.7990 - val_loss: 0.7329 - val_accuracy: 0.8013
# Epoch 5/5
# 4847/4847 [==============================] - 5332s 1s/step - loss: 0.6418 - accuracy: 0.8147 - val_loss: 0.7279 - val_accuracy: 0.8025

# %%
history.history.keys() # 查看history儲存的資訊有哪些
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#Mean absolute error
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.title('accuracy')
plt.ylabel('metrics')
plt.xlabel('epochs')
plt.legend(loc='upper right')

# %%
#Mean square error
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.title('loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
